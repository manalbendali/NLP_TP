# %%
import os
directory = '/kaggle/input/customer-support-on-twitter'
files = os.listdir(directory)
print(files)
# Out:
# ['twcs', 'sample.csv']

# %%
import pandas as pd

file_path = '/kaggle/input/customer-support-on-twitter/sample.csv'

#charger data set juste la colone text
df = pd.read_csv(file_path,usecols=['tweet_id', 'text','text'])

# %%
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237  @AppleSupport causing the reply to be disregar...
# 1    119238  @105835 Your business means a lot to us. Pleas...
# 2    119239  @76328 I really hope you all change but I'm su...
# 3    119240  @105836 LiveChat is online at the moment - htt...
# 4    119241  @VirginTrains see attached error message. I've...

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Téléchargez la liste des mots vides
nltk.download('stopwords')
nltk.download('punkt')

# Charger les données dans un DataFrame
df = pd.read_csv('/kaggle/input/customer-support-on-twitter/sample.csv', usecols=['tweet_id', 'text','text'])

# Mise en minuscules
df['text'] = df['text'].str.lower()
# Afficher les premières lignes du DataFrame après nettoyage
print(df.head())
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>
# [nltk_data] Error loading punkt: <urlopen error [Errno -3] Temporary
# [nltk_data]     failure in name resolution>
#    tweet_id                                               text
# 0    119237  @applesupport causing the reply to be disregar...
# 1    119238  @105835 your business means a lot to us. pleas...
# 2    119239  @76328 i really hope you all change but i'm su...
# 3    119240  @105836 livechat is online at the moment - htt...
# 4    119241  @virgintrains see attached error message. i've...

# %%
# Suppression des ponctuations
df['text'] = df['text'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237  applesupport causing the reply to be disregard...
# 1    119238  105835 your business means a lot to us please ...
# 2    119239  76328 i really hope you all change but im sure...
# 3    119240  105836 livechat is online at the moment  https...
# 4    119241  virgintrains see attached error message ive tr...

# %%
#supprime les mots tel que "is" ,"the" , ... etc
stop_words = set(stopwords.words('english'))
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in word_tokenize(x) if word.lower() not in stop_words]))
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237  applesupport causing reply disregarded tapped ...
# 1    119238  105835 business means lot us please dm name zi...
# 2    119239         76328 really hope change im sure wont dont
# 3    119240  105836 livechat online moment httpstcosy94vtu8...
# 4    119241  virgintrains see attached error message ive tr...

# %%
#suppression des mots frequent
from collections import Counter

# Calculer la fréquence de chaque mot dans le text
word_freq = Counter()
for text in df['text']:
    word_freq.update(text.split())

# Identifier les mots fréquents à supprimer 
SEUIL_FRÉQUENCE = 30
stopwords = set()
for word, freq in word_freq.items():
    if freq > SEUIL_FRÉQUENCE:  # SEUIL_FRÉQUENCE est un nombre que vous définissez
        stopwords.add(word)

# Supprimer les mots fréquents de chaque texte
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in stopwords]))
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237  applesupport causing reply disregarded tapped ...
# 1    119238  105835 business means lot us please dm name zi...
# 2    119239         76328 really hope change im sure wont dont
# 3    119240  105836 livechat online moment httpstcosy94vtu8...
# 4    119241  virgintrains see attached error message ive tr...

# %%
#suppression des mots rares : 
from collections import Counter

# Calculer la fréquence de chaque mot dans le text
word_freq = Counter()
for text in df['text']:
    word_freq.update(text.split())

# Identifier les mots fréquents à supprimer 
SEUIL_FRÉQUENCE_RARE = 1
mots_rares = set(word for word, freq in word_freq.items() if freq <= SEUIL_FRÉQUENCE_RARE)

# Supprimer les mots rares de chaque texte
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in mots_rares]))
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237                                 applesupport reply
# 1    119238           means lot us please dm name code concern
# 2    119239                             hope im sure wont dont
# 3    119240  105836 moment 031 031 option 1 4 3 message cal...
# 4    119241  virgintrains see message ive tried several tim...

# %%
# Stemming : running --> run
ps = PorterStemmer()
df['text'] = df['text'].apply(lambda x: ' '.join([ps.stem(word) for word in word_tokenize(x)]))
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237                                 applesupport repli
# 1    119238             mean lot us pleas dm name code concern
# 2    119239                             hope im sure wont dont
# 3    119240  105836 moment 031 031 option 1 4 3 messag call...
# 4    119241  virgintrain see messag ive tri sever time past...

# %%
# Suppression des émojis, des émoticônes, des URL, des balises HTML
df['text'] = df['text'].apply(lambda x: re.sub(r'\W', ' ', x))
print(df.head())
# Out:
#    tweet_id                                               text
# 0    119237                                 applesupport repli
# 1    119238             mean lot us pleas dm name code concern
# 2    119239                             hope im sure wont dont
# 3    119240  105836 moment 031 031 option 1 4 3 messag call...
# 4    119241  virgintrain see messag ive tri sever time past...
